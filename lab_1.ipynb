# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('apache_logs.txt', 'r') as f:
    lines = f.readlines()

lines = [line for line in lines ]
lines[0]
# Out:
# '83.149.9.216 - - [17/May/2015:10:05:03 +0000] "GET /presentations/logstash-monitorama-2013/images/kibana-search.png HTTP/1.1" 200 203023 "http://semicomplete.com/presentations/logstash-monitorama-2013/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.77 Safari/537.36"\n'

# %%
log_pattern = log_pattern = r'(?P<ip>\d+\.\d+\.\d+\.\d+) - - \[(?P<date>[^\]]+)\] "(?P<request>[A-Z]+) [^"]+" (?P<status_code>\d{3}) (?P<size>\d+) "(?P<referrer>[^"]+)" "(?P<user_agent>[^"]+)"'

# %%
df = []
for line in lines:
    match = re.match(log_pattern, line)
    if match:
        df.append(match.groupdict())

columns = ['ip', 'date', 'request', 'status_code', 'size', 'referrer', 'user_agent']
df = pd.DataFrame(df, columns=columns)

# %%
df.head(5)
# Out:
#              ip                        date request status_code    size  \
# 0  83.149.9.216  17/May/2015:10:05:03 +0000     GET         200  203023
# 1  83.149.9.216  17/May/2015:10:05:43 +0000     GET         200  171717
# 2  83.149.9.216  17/May/2015:10:05:47 +0000     GET         200   26185
# 3  83.149.9.216  17/May/2015:10:05:12 +0000     GET         200    7697
# 4  83.149.9.216  17/May/2015:10:05:07 +0000     GET         200    2892
#
#                                             referrer  \
# 0  http://semicomplete.com/presentations/logstash...
# 1  http://semicomplete.com/presentations/logstash...
# 2  http://semicomplete.com/presentations/logstash...
# 3  http://semicomplete.com/presentations/logstash...
# 4  http://semicomplete.com/presentations/logstash...
#
#                                           user_agent
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...

# %%
df.to_csv('parsed_apache_logs.csv', index=False)

# %% [markdown]
# a.  Визначити кількість користувачів за днями

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%b/%Y:%H:%M:%S %z')

# %%
df['date'] = df['date'].dt.strftime('%Y-%m-%d')
df
# Out:
#                  ip        date request status_code    size  \
# 0      83.149.9.216  2015-05-17     GET         200  203023
# 1      83.149.9.216  2015-05-17     GET         200  171717
# 2      83.149.9.216  2015-05-17     GET         200   26185
# 3      83.149.9.216  2015-05-17     GET         200    7697
# 4      83.149.9.216  2015-05-17     GET         200    2892
# ...             ...         ...     ...         ...     ...
# 9325  100.43.83.137  2015-05-20     GET         200   13358
# 9326   63.140.98.80  2015-05-20     GET         200   14872
# 9327   63.140.98.80  2015-05-20     GET         200   10756
# 9328  66.249.73.135  2015-05-20     GET         200   32352
# 9329   46.105.14.53  2015-05-20     GET         200   14872
#
#                                                referrer  \
# 0     http://semicomplete.com/presentations/logstash...
# 1     http://semicomplete.com/presentations/logstash...
# 2     http://semicomplete.com/presentations/logstash...
# 3     http://semicomplete.com/presentations/logstash...
# 4     http://semicomplete.com/presentations/logstash...
# ...                                                 ...
# 9325                                                  -
# 9326  http://www.semicomplete.com/blog/tags/puppet?f...
# 9327                                                  -
# 9328                                                  -
# 9329                                                  -
#
#                                              user_agent
# 0     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 1     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 4     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# ...                                                 ...
# 9325  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 9326            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9327            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9328  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 9329  UniversalFeedParser/4.2-pre-314-svn +http://fe...
#
# [9330 rows x 7 columns]

# %%
df_unique_ip = df.groupby('date')['ip'].nunique().reset_index()
df_unique_ip
# Out:
#          date   ip
# 0  2015-05-17  325
# 1  2015-05-18  584
# 2  2015-05-19  526
# 3  2015-05-20  478

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_unique_ip['date'], df_unique_ip['ip'], marker='o', linestyle='-')        
plt.title('Unique IPs per Day')
plt.xlabel('Date')
plt.ylabel('Number of Unique IPs')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# b. Ранжувати користувачів за User-Agent

# %%
df
# Out:
#                  ip        date request status_code    size  \
# 0      83.149.9.216  2015-05-17     GET         200  203023
# 1      83.149.9.216  2015-05-17     GET         200  171717
# 2      83.149.9.216  2015-05-17     GET         200   26185
# 3      83.149.9.216  2015-05-17     GET         200    7697
# 4      83.149.9.216  2015-05-17     GET         200    2892
# ...             ...         ...     ...         ...     ...
# 9325  100.43.83.137  2015-05-20     GET         200   13358
# 9326   63.140.98.80  2015-05-20     GET         200   14872
# 9327   63.140.98.80  2015-05-20     GET         200   10756
# 9328  66.249.73.135  2015-05-20     GET         200   32352
# 9329   46.105.14.53  2015-05-20     GET         200   14872
#
#                                                referrer  \
# 0     http://semicomplete.com/presentations/logstash...
# 1     http://semicomplete.com/presentations/logstash...
# 2     http://semicomplete.com/presentations/logstash...
# 3     http://semicomplete.com/presentations/logstash...
# 4     http://semicomplete.com/presentations/logstash...
# ...                                                 ...
# 9325                                                  -
# 9326  http://www.semicomplete.com/blog/tags/puppet?f...
# 9327                                                  -
# 9328                                                  -
# 9329                                                  -
#
#                                              user_agent
# 0     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 1     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 4     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# ...                                                 ...
# 9325  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 9326            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9327            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9328  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 9329  UniversalFeedParser/4.2-pre-314-svn +http://fe...
#
# [9330 rows x 7 columns]

# %%
df['ua_short'] = df['user_agent'].apply(lambda x: x.split(' ')[0])

# %%
df_user_agent = df.groupby('ua_short')['ip'].nunique().reset_index().sort_values(by='ip', ascending=False)
df_user_agent
# Out:
#                ua_short    ip
# 31          Mozilla/5.0  1380
# 30          Mozilla/4.0    86
# 1                     -    47
# 10       FeedBurner/1.0    28
# 35           Opera/9.80    24
# ..                  ...   ...
# 54             ZDM/4.0;     1
# 53          YisouSpider     1
# 60          ia_archiver     1
# 63  nutch-1.4/Nutch-1.4     1
# 65            psbot/0.1     1
#
# [66 rows x 2 columns]

# %%
plt.figure(figsize=(16, 12))
plt.bar(df_user_agent['ua_short'], df_user_agent['ip'])
plt.title('Name of User Agent')  
plt.ylabel('Number of User Agent')
plt.xticks(rotation=90) 
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# c. Ранжувати користувачів за операційними системами

# %%
def operation_system(ua_list):
    os = []
    for ua in df['user_agent']:
        if 'Windows' in ua:
            os.append('Windows')
        elif 'Linux' in ua:
            os.append('Linux')
        elif 'Macintosh' in ua:
            os.append('Macintosh')
        else:
            os.append('Other')
    return os

ua_list = df['user_agent'].tolist()
os_unique = operation_system(ua_list)
os_df = pd.Series (os_unique).value_counts().reset_index()
os_df
# Out:
#        index  count
# 0    Windows   3047
# 1      Other   2760
# 2      Linux   2189
# 3  Macintosh   1334

# %%
plt.figure(figsize=(9, 8))
plt.bar(os_df['index'], os_df['count'])
plt.title('Name of OS')  
plt.ylabel('Number of users')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()

# %% [markdown]
# d. Ранжувати користувачів за країною запиту

# %%
# !pip install geoip2
# Out:
# Collecting geoip2
#   Downloading geoip2-5.1.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.6.2 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from geoip2) (3.11.13)
# Collecting maxminddb<3.0.0,>=2.7.0 (from geoip2)
#   Downloading maxminddb-2.7.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from geoip2) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.6.2->geoip2) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.24.0->geoip2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.24.0->geoip2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.24.0->geoip2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\radom\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.24.0->geoip2) (2025.1.31)
# Downloading geoip2-5.1.0-py3-none-any.whl (27 kB)
# Downloading maxminddb-2.7.0-cp313-cp313-win_amd64.whl (36 kB)
# Installing collected packages: maxminddb, geoip2
# Successfully installed geoip2-5.1.0 maxminddb-2.7.0
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df
# Out:
#                  ip        date request status_code    size  \
# 0      83.149.9.216  2015-05-17     GET         200  203023
# 1      83.149.9.216  2015-05-17     GET         200  171717
# 2      83.149.9.216  2015-05-17     GET         200   26185
# 3      83.149.9.216  2015-05-17     GET         200    7697
# 4      83.149.9.216  2015-05-17     GET         200    2892
# ...             ...         ...     ...         ...     ...
# 9325  100.43.83.137  2015-05-20     GET         200   13358
# 9326   63.140.98.80  2015-05-20     GET         200   14872
# 9327   63.140.98.80  2015-05-20     GET         200   10756
# 9328  66.249.73.135  2015-05-20     GET         200   32352
# 9329   46.105.14.53  2015-05-20     GET         200   14872
#
#                                                referrer  \
# 0     http://semicomplete.com/presentations/logstash...
# 1     http://semicomplete.com/presentations/logstash...
# 2     http://semicomplete.com/presentations/logstash...
# 3     http://semicomplete.com/presentations/logstash...
# 4     http://semicomplete.com/presentations/logstash...
# ...                                                 ...
# 9325                                                  -
# 9326  http://www.semicomplete.com/blog/tags/puppet?f...
# 9327                                                  -
# 9328                                                  -
# 9329                                                  -
#
#                                              user_agent  \
# 0     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 1     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# 4     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1)...
# ...                                                 ...
# 9325  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 9326            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9327            Tiny Tiny RSS/1.11 (http://tt-rss.org/)
# 9328  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 9329  UniversalFeedParser/4.2-pre-314-svn +http://fe...
#
#                                  ua_short
# 0                             Mozilla/5.0
# 1                             Mozilla/5.0
# 2                             Mozilla/5.0
# 3                             Mozilla/5.0
# 4                             Mozilla/5.0
# ...                                   ...
# 9325                          Mozilla/5.0
# 9326                                 Tiny
# 9327                                 Tiny
# 9328                          Mozilla/5.0
# 9329  UniversalFeedParser/4.2-pre-314-svn
#
# [9330 rows x 8 columns]

# %%
import geoip2.database

reader = geoip2.database.Reader('GeoLite2-Country.mmdb')

def user_country(ip):
    try:
        response = reader.country(ip)
        return response.country.name
    except Exception as e:
        print(f"Error for IP {ip}: {e}")
        return 'Unknown'

df['Country'] = df['ip'].apply(lambda x: user_country(x))
country_count = df['Country'].value_counts()
country_count
# Out:
# Country
# United States          3578
# France                  851
# Germany                 545
# India                   413
# Sweden                  358
#                        ...
# Georgia                   1
# Oman                      1
# Pakistan                  1
# Trinidad and Tobago       1
# Azerbaijan                1
# Name: count, Length: 94, dtype: int64

# %%
plt.figure(figsize=(10, 16))
plt.barh(country_count.index, country_count.values)
plt.title('Countries')
plt.xlabel('Number of requests')
plt.gca().invert_yaxis() 
plt.tight_layout()
plt.show()

# %% [markdown]
# Топ країн

# %%
plt.figure(figsize=(10, 16))
plt.bar(country_count.head(10).index, country_count.head(10).values)
plt.title('Top 10 Countries') 
plt.ylabel('Number of requests')
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %% [markdown]
# e. Виокремити пошукових ботів

# %%
bot_keywords = ['bot', 'spider', 'crawl', 'Googlebot', 'Bingbot', 'Yandex', 'Slurp', 'DuckDuckBot', 'Baiduspider']

bots = df[df['user_agent'].str.contains('|'.join(bot_keywords), case=False, na=False)]
bot_counts = bots['user_agent'].value_counts().head(10)

# %%
plt.figure(figsize=(10, 16))
plt.barh(bot_counts.index, bot_counts.values)
plt.title('Top 10 Bots')
plt.xlabel('Number of requests')
plt.gca().invert_yaxis() 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Radom\AppData\Local\Temp\ipykernel_11320\1434714605.py:6: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# f. Детектувати аномалії (якщо такі є)

# %%
df.to_csv('parsed_apache_logs_with_country.csv', index=False)

# %%
df['status_code'].unique()
# Out:
# array(['200', '404', '301', '206', '403', '416', '500'], dtype=object)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
scaler = StandardScaler()
status_scaled = scaler.fit_transform(df[['status_code']])

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
df['cluster'] = kmeans.fit_predict(status_scaled)


distances = np.linalg.norm(status_scaled - kmeans.cluster_centers_[df['cluster']], axis=1)
df['distance_to_centroid'] = distances


threshold = np.percentile(distances, 95)
df['is_anomaly'] = df['distance_to_centroid'] > threshold


df[df['is_anomaly']].head(10)
# Out:
#                   ip        date request status_code   size  \
# 62     66.249.73.185  2015-05-17     GET         404    294
# 173    208.91.156.11  2015-05-17     GET         404    324
# 305  111.199.235.239  2015-05-17     GET         404    364
# 323  111.199.235.239  2015-05-17     GET         404    364
# 345    208.91.156.11  2015-05-17     GET         404    324
# 366   144.76.194.187  2015-05-17     GET         404    292
# 367   144.76.194.187  2015-05-17     GET         404    303
# 413   173.252.73.114  2015-05-17     GET         206  97173
# 579        89.2.87.1  2015-05-17     GET         206  65536
# 580        89.2.87.1  2015-05-17     GET         206  55278
#
#                                               referrer  \
# 62                                                   -
# 173                                                  -
# 305  http://semicomplete.com/presentations/logstash...
# 323  http://semicomplete.com/presentations/logstash...
# 345                                                  -
# 366                                                  -
# 367                                                  -
# 413                                                  -
# 579  http://www.google.fr/url?sa=t&rct=j&q=&esrc=s&...
# 580  http://www.google.fr/url?sa=t&rct=j&q=&esrc=s&...
#
#                                             user_agent  \
# 62   Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 173  Chef Client/10.18.2 (ruby-1.9.3-p327; ohai-6.1...
# 305  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)...
# 323  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)...
# 345  Chef Client/10.18.2 (ruby-1.9.3-p327; ohai-6.1...
# 366                                                  -
# 367                                                  -
# 413  facebookexternalhit/1.1 (+http://www.facebook....
# 579  Mozilla/5.0 (Windows NT 5.1; rv:26.0) Gecko/20...
# 580  Mozilla/5.0 (Windows NT 5.1; rv:26.0) Gecko/20...
#
#                     ua_short        Country  cluster  distance_to_centroid  \
# 62               Mozilla/5.0  United States        1              0.003203
# 173                     Chef  United States        1              0.003203
# 305              Mozilla/5.0          China        1              0.003203
# 323              Mozilla/5.0          China        1              0.003203
# 345                     Chef  United States        1              0.003203
# 366                        -        Germany        1              0.003203
# 367                        -        Germany        1              0.003203
# 413  facebookexternalhit/1.1  United States        0              0.181629
# 579              Mozilla/5.0         France        0              0.181629
# 580              Mozilla/5.0         France        0              0.181629
#
#      is_anomaly
# 62         True
# 173        True
# 305        True
# 323        True
# 345        True
# 366        True
# 367        True
# 413        True
# 579        True
# 580        True

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['status_code'], c=df['is_anomaly'], cmap='coolwarm')
plt.title('Аномалії в статус-кодах (K-Means)')
plt.xlabel('Розмір')
plt.ylabel('HTTP статус-код')
plt.legend()
plt.show()
# Out:
# C:\Users\Radom\AppData\Local\Temp\ipykernel_11320\2403525759.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
